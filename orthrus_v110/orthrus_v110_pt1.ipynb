# %% [markdown]
# <a href="https://colab.research.google.com/github/yc386/orthrus_metaproteomics/blob/main/orthrus_v110_pt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?export=view&id=19rmmQI1H2nIqgU598WROTcUNhOUoXcBP' width='400px' align='right'>
#
# # **Readme**
#
# ---
# Orthrus 🐾 is a hybrid, two-software pipeline that integrates [Casanovo](https://github.com/Noble-Lab/casanovo) (an AI transformer) with [Sage](https://github.com/lazear/sage) (a fast database search engine with advanced features like retention time alignment and machine learning-based rescoring).
#
# Designed to handle large search space and difficulties of selecting databases in metaproteomics and palaeoproteomics, Orthrus leverages de novo sequencing to define sample-specific databases, and uses probability ranking and conventional database searching to control FDRs (false discovery rates).
#
# Orthrus is optimised for online use on Google Colab 🥳
#
# ---

# %% [markdown]
# # **Please note**❗️
# *   Before walking the dog, please change the runtime type to GPU (A100, L4, or T4. A100 most efficient but T4 is free)
# *   If you would like to connect your Google Drive, click the folder image 🗂️ on the left and mount the drive.
# *  Click `File` (top left) and save a copy in Drive or Github

# %% [markdown]
# # Run `Orthrus`

# %%
#@title Add inputs -> click `Runtime` -> `Run all`
#@markdown **Casanovo inputs**
folder_path="/content/drive/Shareddrives/MS_data/mzML/140125_TT"#@param {type:"string"}
#@markdown - a folder contains single or multiple `.mzML` or `.mgf` files for `Casanovo`. Please check only _ (underscore) and no other special characters or space in a file name.
file_type="mzML" #@param ["mzML", "mgf"]
#@markdown - use the drop-down menu to choose the instrument file type

use_default = False #@param {type:"boolean"}
#@markdown **Advanced Options (ignored if using default settings)**

model = "/content/drive/MyDrive/casanovo/models/casanovo4/ckpt/casanovo_nontryptic_worker1.ckpt" #@param {type:"string"}
#@markdown - a model for Casanovo prediction `.ckpt`
config = "/content/drive/MyDrive/casanovo/models/casanovo4/yaml/config_420.yaml" #@param {type:"string"}
#@markdown - a `.yaml` configuration file for Casanovo

#@markdown **Inputs for converting Casanovo results to a `.fasta`**
use_SwissProt = True #@param {type:"boolean"}
#@markdown - use the latest, reviewed SwissProt form the UniProt FTP
database_path=""#@param {type:"string"}
#@markdown - path to a database (`.fasta`) for shortlisting proteins based on de novo results

# %%
#@title install dependencies & modules

# %%time

# !pip install casanovo biopython

import os

if not os.path.isfile("Orthrus_READY"):
  print("installing conda...")
  os.system("wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Mambaforge-Linux-x86_64.sh")
  os.system("bash Mambaforge-Linux-x86_64.sh -bfp /usr/local")
  os.system("touch Orthrus_READY")
  os.system(f"conda install -c bioconda -c conda-forge sage-proteomics -y -q")


import glob
import pandas as pd
import numpy as np
import re
import json
from pyteomics import mztab
from joblib import Parallel, delayed
from itertools import chain
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
import requests
import gzip
import shutil

'''
parse a .mztab file using pyteomics
add naked sequences (without PTMs) & the sequence length
input=path to .mztab file
output=pandas dataframe

'''
pattern = re.compile(r'(.\d*\.?\d+)')

def prep_mztab(mztab_path):
    """
    Prepare and process the MzTab file for analysis.

    Args:
        mztab_path (str): Path to the MzTab file.

    Returns:
        pandas.DataFrame: Processed DataFrame with additional columns.
    """
    m = mztab.MzTab(mztab_path)
    df = m.spectrum_match_table

    if df is None or df.empty:
        raise ValueError(f"{mztab_path} is empty")

    if 'sequence' not in df.columns:
        raise KeyError(f"'sequence' column is missing in the file: {mztab_path}")

    df = df.reset_index(drop=True)

    df1 = df.assign(
        sequence_naked=df['sequence'].str.replace(pattern, '', regex=True)
    )

    df2 = df1.assign(
        nAA=df1['sequence_naked'].str.len()
    )

    df3 = df2.sort_values(by='sequence_naked').drop_duplicates(
        subset='sequence_naked', keep="first"
    ).reset_index(drop=True)

    return df3


def fasta_to_df(fasta_file):
    """
    Convert a .fasta file into a pandas DataFrame.

    Args:
        fasta_file (str): Path to the .fasta file.

    Returns:
        pandas.DataFrame: DataFrame with Protein_ID, Description, Sequence, and UniProt_ID.
    """
    data = []

    for record in SeqIO.parse(fasta_file, "fasta"):
        protein_id = record.id
        description = record.description
        sequence = str(record.seq)

        if not sequence:
            raise ValueError(
                f"Record with ID '{protein_id}' has no sequence in the fasta file."
            )

        data.append((protein_id, description, sequence))

    df = pd.DataFrame(data, columns=["Protein_ID", "Description", "Sequence"])
    df1 = df.assign(UniProt_ID=df["Protein_ID"].str.split("|").str[1])

    return df1


"""
Filter a Casanovo output file based on the maximum value below 0.

`search_engine_score[1]` is a score assigned to each prediction by Casanovo, max=1.
If negative, the prediction is outside the mass tolerance.

Input: pandas DataFrame.
Output: pandas DataFrame.
"""

def casa_filter(df):
    """
    Filter a Casanovo output file based on the maximum value below 0.
    `search_engine_score[1]` is a score assigned to each prediction by Casanovo, max=1.
    If negative, the prediction is outside the mass tolerance.

    Args:
        df (pandas.DataFrame): Input DataFrame.

    Returns:
        pandas.DataFrame: Filtered DataFrame.
    """
    np_array = df['search_engine_score[1]'].to_numpy()
    max_below_zero = np_array[np_array < 0].max()
    df1 = df[df['search_engine_score[1]'] >= max_below_zero]
    return df1

def get_seq_tags(sequence, k):

    return set(sequence[i:i + k] for i in range(len(sequence) - k + 1))


'''
match de novo-based tags with database tags
I=L in a reference database
inputs=path to fasta, filtered casanovo output dataframe, tag size=k, chunk size=10000 for processing
output=pandas dataframe

'''

def matching_count_v5(df, df1, k, chunk_size=10000):

    sequence_set = get_seq_tags(''.join(chain.from_iterable(df1['sequence_naked'].astype(str))), k)
    print(f"📝 {len(sequence_set)} tags regenerated. Starting matching...")
    result_df = pd.DataFrame()

    for start in range(0, len(df), chunk_size):
        chunk = df.iloc[start:start + chunk_size].copy()
        chunk['seq_tags'] = chunk['Sequence'].astype(str).str.replace('I', 'L').apply(lambda x: get_seq_tags(x, k))
        chunk['matched_count'] = chunk['seq_tags'].apply(lambda seq_tags: len(seq_tags & sequence_set))
        chunk = chunk.assign(matched=chunk['matched_count'].apply(lambda x: 1 if x >= 2 else 0))
        result_df = pd.concat([result_df, chunk], ignore_index=True)

    total_matches = result_df['matched_count'].sum()
    print(f"Completed! {total_matches} matched 👍")
    return result_df

#get tryptic peptides per database entry
def count_tryptic_peptides(sequence):

    pattern = r'(?<=[KR])'
    peptides = re.split(pattern, sequence)
    filtered_peptides = [peptide for peptide in peptides if len(peptide) >= 6]
    return len(filtered_peptides)


#prepare a dataframe for NB classification
def prep_Bayes(df):

    print('🧑‍💻 Start Bayes probabilistic ranking...')
    df1 = df.assign(
        length=df['Sequence'].astype(str).str.len(),
        tryptic_count=df['Sequence'].apply(count_tryptic_peptides),
        tag_count=df['seq_tags'].apply(len)
    )
    df2 = df1.assign(
        SAF=df1['matched_count'] / df1['length'],
        try_ratio=df1['tryptic_count'] / df1['tag_count']
    )
    return df2

'''
ranking matched proteins based on SAF and try_ratio
values normalised before NB classification
most probable matches (>= 95%) are shortlised

'''
def get_bayes_ranking_test(df, threshold=0.95):

    m = prep_Bayes(df)
    required_columns = {'SAF', 'try_ratio', 'matched'}

    if not required_columns.issubset(m.columns):
        missing_cols = required_columns - set(m.columns)
        raise ValueError(f"Missing columns in DataFrame: {missing_cols}")

    m1 = m[m['tag_count'] > 0]
    X = m1[['SAF', 'try_ratio']].to_numpy()
    y = m1['matched'].to_numpy()

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X.reshape(-1, 1)).reshape(*X.shape)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=7)

    gnb = GaussianNB()
    gnb.fit(X_train, y_train)

    y_pred = gnb.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"✅ Gaussian Naive Bayes model ▶️ accuracy: {accuracy:.4f}, precision: {precision:.4f}, f1: {f1:.4f}")

    whole_pred = gnb.predict(X_scaled)
    class_probabilities = gnb.predict_proba(X_scaled)

    m2 = m1.assign(pred=class_probabilities[:, 1])
    m3 = m2[m2['pred'] >= threshold]
    return m3


#combine previous functions together to output a shortlisted .fasta

def matching_ranking_to_fasta_v5(mztab_path, fasta_df):

    p = prep_mztab(mztab_path)
    p1 = casa_filter(p)
    k = int(p1['nAA'].median())
    m = matching_count_v5(fasta_df, p1, k, chunk_size=10000)
    m1 = get_bayes_ranking_test(m)

    seq_records = []
    for _, row in m1.iterrows():
        header_id = f"{row['Description']}"
        sequence = Seq(row['Sequence'])
        description = ""
        seq_record = SeqRecord(sequence, id=header_id, description=description)
        seq_records.append(seq_record)

    output_fasta_filepath = mztab_path.replace('.mztab', '_matched.fasta')
    with open(output_fasta_filepath, 'w') as output_file:
        SeqIO.write(seq_records, output_file, 'fasta')

    print(f"🎊 Number of protein entries in the output fasta: {m1.shape[0]}")



#generate a de novo-first, experiment-specific .fasta for each input
def process_all_mztab_files_v2(folder_path, database_path):

    mztab_filepaths = glob.glob(f"{folder_path}/*.mztab")
    print(f"🗂️ {len(mztab_filepaths)} file(s) collecting from {folder_path}...")
    fas = fasta_to_df(database_path)
    fasta_df = pd.DataFrame.from_dict(fas)
    print(f"⬆️ {database_path} loaded")
    print(f"📤 No. of proteins in the reference fasta: {fasta_df.shape[0]}")

    for mztab in mztab_filepaths:
        print(f"🚀 Processing file: {mztab}")
        matching_ranking_to_fasta_v5(mztab, fasta_df)
# Out:
# Collecting casanovo
#   Downloading casanovo-4.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting appdirs (from casanovo)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting lightning>=2.0 (from casanovo)
#   Downloading lightning-2.5.0.post0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from casanovo) (8.1.8)
# Collecting depthcharge-ms<0.3.0,>=0.2.3 (from casanovo)
#   Downloading depthcharge_ms-0.2.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from casanovo) (8.4.0)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from casanovo) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from casanovo) (2.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from casanovo) (5.9.5)
# Collecting PyGithub (from casanovo)
#   Downloading PyGithub-2.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from casanovo) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from casanovo) (2.32.3)
# Collecting rich-click>=1.6.1 (from casanovo)
#   Downloading rich_click-1.8.5-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from casanovo) (1.6.0)
# Collecting spectrum_utils (from casanovo)
#   Downloading spectrum_utils-0.4.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from casanovo) (2.17.1)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from casanovo) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from casanovo) (4.67.1)
# Collecting pyteomics>=4.4.2 (from depthcharge-ms<0.3.0,>=0.2.3->casanovo)
#   Downloading pyteomics-4.7.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numba>=0.48.0 in /usr/local/lib/python3.11/dist-packages (from depthcharge-ms<0.3.0,>=0.2.3->casanovo) (0.60.0)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from depthcharge-ms<0.3.0,>=0.2.3->casanovo) (5.3.0)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from depthcharge-ms<0.3.0,>=0.2.3->casanovo) (3.12.1)
# Requirement already satisfied: einops>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from depthcharge-ms<0.3.0,>=0.2.3->casanovo) (0.8.0)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (2024.10.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0->casanovo)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->casanovo) (24.2)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning>=2.0->casanovo)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->casanovo) (4.12.2)
# Collecting pytorch-lightning (from lightning>=2.0->casanovo)
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->casanovo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->casanovo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->casanovo) (2024.2)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click>=1.6.1->casanovo) (13.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->casanovo) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1->casanovo) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->casanovo) (1.3.0)
# Collecting pynacl>=1.4.0 (from PyGithub->casanovo)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->casanovo) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub->casanovo) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from PyGithub->casanovo) (1.2.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->casanovo) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->casanovo) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->casanovo) (2024.12.14)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->casanovo) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->casanovo) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->casanovo) (3.5.0)
# Collecting fastobo (from spectrum_utils->casanovo)
#   Downloading fastobo-0.12.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting lark>=1.0 (from spectrum_utils->casanovo)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from spectrum_utils->casanovo) (3.10.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->casanovo) (3.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (3.11.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->spectrum_utils->casanovo) (3.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.48.0->depthcharge-ms<0.3.0,>=0.2.3->casanovo) (0.43.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->casanovo) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->PyGithub->casanovo) (1.17.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click>=1.6.1->casanovo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click>=1.6.1->casanovo) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->casanovo) (3.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->PyGithub->casanovo) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->casanovo) (1.18.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub->casanovo) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click>=1.6.1->casanovo) (0.1.2)
# Downloading casanovo-4.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.0 MB/s eta 0:00:00
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 45.3 MB/s eta 0:00:00
# Downloading depthcharge_ms-0.2.3-py3-none-any.whl (27 kB)
# Downloading lightning-2.5.0.post0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 52.2 MB/s eta 0:00:00
# Downloading rich_click-1.8.5-py3-none-any.whl (35 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading PyGithub-2.5.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.9/375.9 kB 24.7 MB/s eta 0:00:00
# Downloading spectrum_utils-0.4.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.2 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 12.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 54.0 MB/s eta 0:00:00
# Downloading pyteomics-4.7.5-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 kB 18.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 52.1 MB/s eta 0:00:00
# Downloading fastobo-0.12.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 56.1 MB/s eta 0:00:00
# Installing collected packages: pyteomics, appdirs, lightning-utilities, lark, fastobo, biopython, pynacl, spectrum_utils, rich-click, torchmetrics, PyGithub, depthcharge-ms, pytorch-lightning, lightning, casanovo
# Successfully installed PyGithub-2.5.0 appdirs-1.4.4 biopython-1.85 casanovo-4.3.0 depthcharge-ms-0.2.3 fastobo-0.12.3 lark-1.2.2 lightning-2.5.0.post0 lightning-utilities-0.11.9 pynacl-1.5.0 pyteomics-4.7.5 pytorch-lightning-2.5.0.post0 rich-click-1.8.5 spectrum_utils-0.4.2 torchmetrics-1.6.1
# installing conda...
# CPU times: user 3.18 s, sys: 133 ms, total: 3.32 s
# Wall time: 15.7 s

# %%
#@title Run `Casanovo` for de novo

if use_default:
    folder = glob.glob(f"{folder_path}/*.{file_type}")
    for instrument_file in folder:
        output_path = instrument_file.replace(f".{file_type}", ".mztab")
        # !casanovo sequence {instrument_file} -v info -o {output_path}
else:
    folder = glob.glob(f"{folder_path}/*.{file_type}")
    for instrument_file in folder:
        output_path = instrument_file.replace(f".{file_type}", ".mztab")
        # !casanovo sequence {instrument_file} -m {model} -c {config} -v info -o {output_path}
# Out:
# 2025-01-17 14:47:38.910348: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 14:47:38.927846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 14:47:38.949665: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 14:47:38.956311: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 14:47:38.971748: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 14:47:40.367002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0259_EXP3_1010986_ONJ_TR_MC_TT_S6_ABC.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0259_EXP3_1010986_ONJ_TR_MC_TT_S6_ABC.mzML: 100% 11638/11638 [00:08<00:00, 1334.09spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 11/11 [01:58<00:00, 10.79s/it]
# INFO: DONE!
# 2025-01-17 14:51:00.331240: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 14:51:00.349588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 14:51:00.370527: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 14:51:00.376979: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 14:51:00.392095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 14:51:01.839717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0324_EXP3_1010987_ONJ_TR_MC_TT_S6_ABC_W.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0324_EXP3_1010987_ONJ_TR_MC_TT_S6_ABC_W.mzML: 100% 10666/10666 [00:07<00:00, 1345.42spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:02<00:00, 12.23s/it]
# INFO: DONE!
# 2025-01-17 14:53:50.934907: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 14:53:50.953246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 14:53:50.974317: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 14:53:50.980784: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 14:53:50.996292: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 14:53:52.386166: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0348_EXP3_1010988_ONJ_TR_MC_TT_S7_ABC.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0348_EXP3_1010988_ONJ_TR_MC_TT_S7_ABC.mzML: 100% 11259/11259 [00:08<00:00, 1402.06spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 11/11 [02:18<00:00, 12.55s/it]
# INFO: DONE!
# 2025-01-17 14:56:57.438853: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 14:56:57.457683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 14:56:57.479188: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 14:56:57.485784: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 14:56:57.501664: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 14:56:58.903906: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0412_EXP3_1010989_ONJ_TR_MC_TT_S12_ABC.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0412_EXP3_1010989_ONJ_TR_MC_TT_S12_ABC.mzML: 100% 10610/10610 [00:07<00:00, 1380.62spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:20<00:00, 14.05s/it]
# INFO: DONE!
# 2025-01-17 15:00:04.623756: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:00:04.641657: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:00:04.663377: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:00:04.670888: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:00:04.687627: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:00:06.085361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0436_EXP3_1010990_ONJ_TR_MC_TT_S12_ABC_W.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0436_EXP3_1010990_ONJ_TR_MC_TT_S12_ABC_W.mzML: 100% 10480/10480 [00:07<00:00, 1385.27spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:08<00:00, 12.82s/it]
# INFO: DONE!
# 2025-01-17 15:03:02.744927: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:03:02.763523: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:03:02.784674: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:03:02.791205: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:03:02.806796: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:03:04.191114: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0500_EXP3_1010991_ONJ_TR_MC_TT_BLANK_ABC.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0500_EXP3_1010991_ONJ_TR_MC_TT_BLANK_ABC.mzML: 100% 12359/12359 [00:08<00:00, 1382.65spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 12/12 [02:53<00:00, 14.43s/it]
# INFO: DONE!
# 2025-01-17 15:06:51.213114: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:06:51.231208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:06:51.252229: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:06:51.258751: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:06:51.273911: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:06:52.716704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0525_EXP3_1010992_ONJ_TR_MC_TT_S6_GUHCL.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0525_EXP3_1010992_ONJ_TR_MC_TT_S6_GUHCL.mzML: 100% 11703/11703 [00:08<00:00, 1395.22spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 11/11 [02:11<00:00, 11.94s/it]
# INFO: DONE!
# 2025-01-17 15:09:54.802598: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:09:54.820557: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:09:54.841506: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:09:54.848027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:09:54.863145: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:09:56.309028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0549_EXP3_1010993_ONJ_TR_MC_TT_S6_GUHCL_W.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0549_EXP3_1010993_ONJ_TR_MC_TT_S6_GUHCL_W.mzML: 100% 10508/10508 [00:07<00:00, 1391.30spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [01:59<00:00, 11.98s/it]
# INFO: DONE!
# 2025-01-17 15:12:43.731593: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:12:43.749534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:12:43.770774: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:12:43.777203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:12:43.792407: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:12:45.227718: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0613_EXP3_1010994_ONJ_TR_MC_TT_S12_GUHCL.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0613_EXP3_1010994_ONJ_TR_MC_TT_S12_GUHCL.mzML: 100% 10454/10454 [00:07<00:00, 1371.38spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:13<00:00, 13.32s/it]
# INFO: DONE!
# 2025-01-17 15:15:48.307770: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:15:48.326714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:15:48.348946: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:15:48.355828: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:15:48.372114: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:15:49.807944: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0637_EXP3_1010995_ONJ_TR_MC_TT_S12_GUHCL_W.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0637_EXP3_1010995_ONJ_TR_MC_TT_S12_GUHCL_W.mzML: 100% 10378/10378 [00:07<00:00, 1390.66spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:04<00:00, 12.49s/it]
# INFO: DONE!
# 2025-01-17 15:18:44.963166: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-17 15:18:44.981173: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-17 15:18:45.002263: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-17 15:18:45.008791: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-17 15:18:45.024242: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 15:18:46.460848: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 454
# INFO: Casanovo version 4.3.0
# INFO: Sequencing peptides from:
# INFO:   /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0701_EXP3_1010996_ONJ_TR_MC_TT_BLANK_GUHCL.mzML
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO: Reading 1 files...
# /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0701_EXP3_1010996_ONJ_TR_MC_TT_BLANK_GUHCL.mzML: 100% 10448/10448 [00:07<00:00, 1406.40spectra/s]
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 10/10 [02:10<00:00, 13.06s/it]
# INFO: DONE!

# %%
#@title Convert `Casanovo` results to .fasta per experiment

if use_SwissProt:
    url = "https://ftp.uniprot.org/pub/databases/uniprot/knowledgebase/complete/uniprot_sprot.fasta.gz"
    output_file = "uniprot_sprot.fasta.gz"
    decompressed_file = "uniprot_sprot.fasta"

    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(output_file, 'wb') as f:
            shutil.copyfileobj(response.raw, f)
        print(f"{output_file} downloaded successfully.")
    else:
        print(f"Failed to download {output_file}, status code: {response.status_code}")

    with gzip.open(output_file, 'rb') as f_in:
        with open(decompressed_file, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)

    sprot_path = "uniprot_sprot.fasta"
    process_all_mztab_files_v2(folder_path, sprot_path)

else:
    process_all_mztab_files_v2(folder_path, database_path)
# Out:
# uniprot_sprot.fasta.gz downloaded successfully.
# 🗂️ 11 file(s) collecting from /content/drive/Shareddrives/MS_data/mzML/140125_TT...
# ⬆️ uniprot_sprot.fasta loaded
# 📤 No. of proteins in the reference fasta: 572619
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0259_EXP3_1010986_ONJ_TR_MC_TT_S6_ABC.mztab
# 📝 11414 tags regenerated. Starting matching...
# Completed! 6759 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 0.9989, precision: 0.7708, f1: 0.8706
# 🎊 Number of protein entries in the output fasta: 2600
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0324_EXP3_1010987_ONJ_TR_MC_TT_S6_ABC_W.mztab
# 📝 896 tags regenerated. Starting matching...
# Completed! 47 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 0.6667, f1: 0.8000
# 🎊 Number of protein entries in the output fasta: 18
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0348_EXP3_1010988_ONJ_TR_MC_TT_S7_ABC.mztab
# 📝 6091 tags regenerated. Starting matching...
# Completed! 1020 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 0.9999, precision: 0.8333, f1: 0.9091
# 🎊 Number of protein entries in the output fasta: 259
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0412_EXP3_1010989_ONJ_TR_MC_TT_S12_ABC.mztab
# 📝 5392 tags regenerated. Starting matching...
# Completed! 1591 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 0.9997, precision: 0.6076, f1: 0.7559
# 🎊 Number of protein entries in the output fasta: 444
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0436_EXP3_1010990_ONJ_TR_MC_TT_S12_ABC_W.mztab
# 📝 601 tags regenerated. Starting matching...
# Completed! 52 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 1.0000, f1: 1.0000
# 🎊 Number of protein entries in the output fasta: 15
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0500_EXP3_1010991_ONJ_TR_MC_TT_BLANK_ABC.mztab
# 📝 10937 tags regenerated. Starting matching...
# Completed! 422 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 0.7500, f1: 0.8571
# 🎊 Number of protein entries in the output fasta: 45
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0525_EXP3_1010992_ONJ_TR_MC_TT_S6_GUHCL.mztab
# 📝 6402 tags regenerated. Starting matching...
# Completed! 1419 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 0.9989, precision: 0.2849, f1: 0.4434
# 🎊 Number of protein entries in the output fasta: 837
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0549_EXP3_1010993_ONJ_TR_MC_TT_S6_GUHCL_W.mztab
# 📝 850 tags regenerated. Starting matching...
# Completed! 36 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 1.0000, f1: 1.0000
# 🎊 Number of protein entries in the output fasta: 8
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0613_EXP3_1010994_ONJ_TR_MC_TT_S12_GUHCL.mztab
# 📝 3615 tags regenerated. Starting matching...
# Completed! 573 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 0.8421, f1: 0.9143
# 🎊 Number of protein entries in the output fasta: 75
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0637_EXP3_1010995_ONJ_TR_MC_TT_S12_GUHCL_W.mztab
# 📝 1411 tags regenerated. Starting matching...
# Completed! 260 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 0.9999, precision: 0.3333, f1: 0.5000
# 🎊 Number of protein entries in the output fasta: 63
# 🚀 Processing file: /content/drive/Shareddrives/MS_data/mzML/140125_TT/20250115-0701_EXP3_1010996_ONJ_TR_MC_TT_BLANK_GUHCL.mztab
# 📝 6088 tags regenerated. Starting matching...
# Completed! 642 matched 👍
# 🧑‍💻 Start Bayes probabilistic ranking...
# ✅ Gaussian Naive Bayes model ▶️ accuracy: 1.0000, precision: 0.7692, f1: 0.8696
# 🎊 Number of protein entries in the output fasta: 67
